# %%
# !pip install scikit-uplift pandas -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.1/42.1 kB 1.5 MB/s eta 0:00:00

# %%
from sklift.datasets import fetch_lenta

dataset = fetch_lenta()


data      = dataset.data       # 687k строк, 193 признака
target    = dataset.target     # 0/1 — купил или нет
treatment = dataset.treatment  # test/control

print(data.shape, target.shape, treatment.shape)
# Out:
# Lenta dataset:   0%|          | 0.00/145M [00:00<?, ?iB/s]
# (687029, 193) (687029,) (687029,)

# %%
data.head(30)
# Out:
#      age  cheque_count_12m_g20  cheque_count_12m_g21  cheque_count_12m_g25  \
# 0   47.0                   3.0                  22.0                  19.0
# 1   57.0                   1.0                   0.0                   2.0
# 2   38.0                   7.0                   0.0                  15.0
# 3   65.0                   6.0                   3.0                  25.0
# 4   61.0                   0.0                   1.0                   2.0
# 5   27.0                   0.0                   0.0                   7.0
# 6   57.0                   1.0                   3.0                   0.0
# 7   32.0                   1.0                   5.0                   7.0
# 8   69.0                   1.0                   1.0                   5.0
# 9   36.0                   1.0                   1.0                   1.0
# 10  35.0                   0.0                   0.0                   0.0
# ...
